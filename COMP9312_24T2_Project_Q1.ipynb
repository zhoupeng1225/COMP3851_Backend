# %% [markdown]
# <a href="https://colab.research.google.com/github/zhoupeng1225/COMP3851_Backend/blob/main/COMP9312_24T2_Project_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #COMP9312_Project_Q1: Shortest Distance Query

# %% [markdown]
# For more information about the project, please refer to the [project specification](https://cgi.cse.unsw.edu.au/~cs9312/24T2/project/). You can edit this file and add anything you like. We will only use the code cell of the `ShortestDistanceQuery` class for testing. You can add descriptions and some theoretical analysis (e.g. index space, query time complexity, and index time complexity) to this file without creating a separate PDF document.
#
# **Note**: Make sure to **sequentially run all cells in each section** in order to carry over intermediate variables/packages to the next cell.

# %% [markdown]
# ## 1. Code Template
# You need to implement the `ShortestDistanceQuery` class to support shortest distance queries for large graphs (e.g. hundreds of millions of vertices and edges). A code template is given below.
#
# The `ShortestDistanceQuery` class is initialized by a graph `G`. The data structure of `G` will be presented in the next section. The class calls the function `preprocess` to precompute some index structure for `G`. The `query` function has two inputs: `vertex_u` and `vertex_v`. The function outputs the shortest distance between `vertex_u` and `vertex_v` in `G`.

# %%
################################################################################
# You can import any Python Standard Library modules~
from collections import deque
################################################################################

class ShortestDistanceQuery(object):
    def __init__(self, G):
        self.G = G
        ################################################################################
        # TODO: You may add some index data structures here~
        # analyze the space usage/complexity of the index (all additional data structures)~
        ################################################################################
        self.preprocess(G)

    def preprocess(self, G):
        ################################################################################
        # TODO: Your code here~
        # precompute some index data structures for G and use them to speed up query processing
        # analyze the time complexity of preprocess()
        ################################################################################
        return

    def query(self, vertex_u, vertex_v):
        shortest_distance = 0
        ################################################################################
        # TODO: Your code here~
        # Input: vertex_u, vertex_v
        # Output: the shortest distance between vertex_u and vertex_v
        # analyze the time complexity of query()
        # Initialize a queue for BFS
        ################################################################################
        return shortest_distance

    ################################################################################
    # You can define any auxiliary functions~
    ################################################################################

# %% [markdown]
# ## 2. Graph Data Structure
# The following is the data stucture of the input graph `G`.

# %%
################################################################################
# Do not edit this code cell.
################################################################################

class UndirectedUnweightedGraph(object):
    def __init__(self, edge_list):
        self.adj_list = []
        self.vertex_num = 0
        self.edge_num = 0
        info = True
        for [vertex_u, vertex_v] in edge_list:
            if info:
                info = False
                self.vertex_num = vertex_u
                self.edge_num = vertex_v
                self.adj_list = [list() for _ in range(self.vertex_num)]
            else:
                self.adj_list[vertex_u].append(vertex_v)
                self.adj_list[vertex_v].append(vertex_u)

# %% [markdown]
# ## 3. How to test your code

# %% [markdown]
# ### 3.1 Download the sample dataset.
#
# Running the following command will create the **COMP9312-24T2-Project** folder, which contains the files for the three datasets.
#
# > **Cora** (2k vertices) is a real citation graph, **map_BJ_part** (4k vertices) is a real road network for a small area of Beijing, and **map_NY_part** (7k vertices) is a real road network for a small area of New York. For the two road networks, we erase the weight of each edge in the original dataset to generate unweighted graphs for simplicity.
#
# There are three files for each dataset, where ***.graph** includes the graph information and all graph edges (vertex IDs are consecutive and start from 0), ***.query** includes a set of queries for testing. ***.answer** includes the correct answer to each query for your reference.
#
# If the dataset already exists, an error like "*destination path 'COMP9312-24T2-Project' already exists*" will appear.
#
# **NOTE**: We will test the code using different datasets.

# %%
# !git clone https://github.com/kevinChnn/COMP9312-24T2-Project
# Out:
# Cloning into 'COMP9312-24T2-Project'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 35 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (35/35), 161.98 KiB | 825.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# ### 3.2 The main function
#
# Our test procedure first loads the graph dataset and the query dataset. Then, it calls the `ShortestDistanceQuery` class to preprocess the graph. After that, it will run each query and test its efficiency and correctness.

# %%
import time
import numpy as np

if __name__ == "__main__":

    print('\n######## Loading the dataset...')
    edge_list = np.loadtxt('./COMP9312-24T2-Project/cora.graph', dtype=int)
    query_list = np.loadtxt('./COMP9312-24T2-Project/cora-sd.query', dtype=int)
    # edge_list = np.loadtxt('./COMP9312-24T2-Project/map_BJ_part.graph', dtype=int)
    # query_list = np.loadtxt('./COMP9312-24T2-Project/map_BJ_part-sd.query', dtype=int)
    # edge_list = np.loadtxt('./COMP9312-24T2-Project/map_NY_part.graph', dtype=int)
    # query_list = np.loadtxt('./COMP9312-24T2-Project/map_NY_part-sd.query', dtype=int)
    G = UndirectedUnweightedGraph(edge_list)

    print('\n######## Preprocessing the graph...')
    start_preprocessing = time.time()
    SDQ = ShortestDistanceQuery(G)
    end_preprocessing = time.time()
    print("Preprocessing time: {:.8f}".format(end_preprocessing-start_preprocessing))

    print('\n######## Query Testing...')
    start_query = time.time()
    for i in range(query_list.shape[0]):
        distance = SDQ.query(query_list[i][0], query_list[i][1])
        print("The shortest distance between {} and {} is: {}".format(query_list[i][0], query_list[i][1], query_list[i][2]==distance))
    end_query = time.time()
    print("Average query time: {:.8f}".format((end_query-start_query)/query_list.shape[0]))
# Out:
# ######## Loading the dataset...
#
# ######## Preprocessing the graph...
# Preprocessing time: 0.00000596
#
# ######## Query Testing...
# The shortest distance between 93 and 1407 is: False
# The shortest distance between 1970 and 2685 is: False
# The shortest distance between 2604 and 1182 is: False
# The shortest distance between 788 and 2600 is: False
# The shortest distance between 719 and 261 is: False
# The shortest distance between 1671 and 293 is: False
# The shortest distance between 1148 and 1297 is: False
# The shortest distance between 2378 and 1485 is: False
# The shortest distance between 1473 and 2213 is: False
# The shortest distance between 780 and 167 is: False
# The shortest distance between 1573 and 603 is: False
# The shortest distance between 232 and 1803 is: False
# The shortest distance between 2298 and 1304 is: False
# The shortest distance between 1417 and 1779 is: False
# The shortest distance between 521 and 1080 is: False
# The shortest distance between 114 and 2168 is: False
# The shortest distance between 2444 and 1863 is: False
# The shortest distance between 433 and 737 is: False
# The shortest distance between 2641 and 1300 is: False
# The shortest distance between 2010 and 1514 is: False
# The shortest distance between 2421 and 997 is: False
# The shortest distance between 765 and 733 is: False
# The shortest distance between 1145 and 612 is: False
# The shortest distance between 380 and 709 is: False
# The shortest distance between 2358 and 2300 is: False
# The shortest distance between 1367 and 1935 is: False
# The shortest distance between 821 and 1361 is: False
# The shortest distance between 1945 and 1267 is: False
# The shortest distance between 1800 and 759 is: False
# The shortest distance between 215 and 1363 is: False
# The shortest distance between 2035 and 1629 is: False
# The shortest distance between 276 and 1787 is: False
# The shortest distance between 501 and 1557 is: False
# The shortest distance between 1218 and 2232 is: False
# The shortest distance between 586 and 2578 is: False
# The shortest distance between 479 and 2246 is: False
# The shortest distance between 1811 and 1785 is: False
# The shortest distance between 143 and 362 is: False
# The shortest distance between 1696 and 1296 is: False
# The shortest distance between 830 and 2138 is: False
# The shortest distance between 2034 and 2683 is: False
# The shortest distance between 306 and 133 is: False
# The shortest distance between 2526 and 646 is: False
# The shortest distance between 665 and 112 is: False
# The shortest distance between 1439 and 1346 is: False
# The shortest distance between 406 and 2484 is: False
# The shortest distance between 666 and 166 is: False
# The shortest distance between 2146 and 2590 is: False
# The shortest distance between 1006 and 1643 is: False
# The shortest distance between 2469 and 534 is: False
# The shortest distance between 420 and 1615 is: False
# The shortest distance between 628 and 928 is: False
# The shortest distance between 1812 and 386 is: False
# The shortest distance between 2622 and 640 is: False
# The shortest distance between 873 and 1241 is: False
# The shortest distance between 2230 and 2550 is: False
# The shortest distance between 858 and 2647 is: False
# The shortest distance between 1522 and 2092 is: False
# The shortest distance between 897 and 494 is: False
# The shortest distance between 1976 and 267 is: False
# The shortest distance between 99 and 1305 is: False
# The shortest distance between 1009 and 1151 is: False
# The shortest distance between 584 and 2551 is: False
# The shortest distance between 194 and 920 is: False
# The shortest distance between 1486 and 567 is: False
# The shortest distance between 436 and 994 is: False
# The shortest distance between 1440 and 1349 is: False
# The shortest distance between 682 and 1975 is: False
# The shortest distance between 1755 and 129 is: False
# The shortest distance between 295 and 1748 is: False
# The shortest distance between 826 and 971 is: False
# The shortest distance between 1869 and 1325 is: False
# The shortest distance between 2077 and 515 is: False
# The shortest distance between 1199 and 2030 is: False
# The shortest distance between 378 and 2442 is: False
# The shortest distance between 698 and 2389 is: False
# The shortest distance between 2537 and 7 is: False
# The shortest distance between 1694 and 2198 is: False
# The shortest distance between 2128 and 2626 is: False
# The shortest distance between 195 and 1162 is: False
# The shortest distance between 1177 and 1205 is: False
# The shortest distance between 1049 and 917 is: False
# The shortest distance between 2183 and 2528 is: False
# The shortest distance between 2371 and 2270 is: False
# The shortest distance between 2270 and 1184 is: False
# The shortest distance between 2515 and 1132 is: False
# The shortest distance between 1162 and 2413 is: False
# The shortest distance between 365 and 2148 is: False
# The shortest distance between 738 and 2533 is: False
# The shortest distance between 653 and 1757 is: False
# The shortest distance between 1753 and 2037 is: False
# The shortest distance between 1713 and 722 is: False
# The shortest distance between 8 and 1508 is: False
# The shortest distance between 2569 and 1261 is: False
# The shortest distance between 1913 and 2440 is: False
# The shortest distance between 123 and 922 is: False
# The shortest distance between 706 and 1535 is: False
# The shortest distance between 1540 and 524 is: False
# The shortest distance between 234 and 1809 is: False
# The shortest distance between 639 and 2275 is: False
# The shortest distance between 2396 and 1027 is: False
# The shortest distance between 446 and 1944 is: False
# The shortest distance between 2684 and 28 is: False
# The shortest distance between 2371 and 39 is: False
# The shortest distance between 2123 and 2621 is: False
# The shortest distance between 73 and 1744 is: False
# The shortest distance between 1111 and 1279 is: False
# The shortest distance between 201 and 1712 is: False
# The shortest distance between 1811 and 1909 is: False
# The shortest distance between 2402 and 456 is: False
# The shortest distance between 2336 and 2211 is: False
# The shortest distance between 593 and 238 is: False
# The shortest distance between 583 and 963 is: False
# The shortest distance between 1829 and 2142 is: False
# The shortest distance between 2509 and 2352 is: False
# The shortest distance between 326 and 523 is: False
# The shortest distance between 35 and 1906 is: False
# The shortest distance between 1613 and 593 is: False
# The shortest distance between 1213 and 1608 is: False
# The shortest distance between 345 and 1201 is: False
# The shortest distance between 1421 and 1342 is: False
# The shortest distance between 1147 and 1777 is: False
# The shortest distance between 1447 and 2680 is: False
# The shortest distance between 1598 and 2029 is: False
# The shortest distance between 931 and 1121 is: False
# The shortest distance between 25 and 129 is: False
# The shortest distance between 1382 and 751 is: False
# The shortest distance between 79 and 1212 is: False
# The shortest distance between 2036 and 2378 is: False
# The shortest distance between 1092 and 32 is: False
# The shortest distance between 772 and 1937 is: False
# The shortest distance between 1289 and 2393 is: False
# The shortest distance between 1128 and 544 is: False
# The shortest distance between 70 and 1049 is: False
# The shortest distance between 2080 and 2384 is: False
# The shortest distance between 955 and 2313 is: False
# The shortest distance between 318 and 1184 is: False
# The shortest distance between 756 and 2447 is: False
# The shortest distance between 2341 and 2252 is: False
# The shortest distance between 1810 and 1665 is: False
# The shortest distance between 741 and 2483 is: False
# The shortest distance between 1674 and 31 is: False
# The shortest distance between 2543 and 1033 is: False
# The shortest distance between 445 and 561 is: False
# The shortest distance between 396 and 2219 is: False
# The shortest distance between 2675 and 1260 is: False
# The shortest distance between 583 and 1622 is: False
# The shortest distance between 1602 and 2417 is: False
# The shortest distance between 144 and 791 is: False
# The shortest distance between 2012 and 2151 is: False
# The shortest distance between 59 and 2402 is: False
# The shortest distance between 1600 and 197 is: False
# The shortest distance between 1816 and 23 is: False
# The shortest distance between 415 and 334 is: False
# The shortest distance between 1900 and 78 is: False
# The shortest distance between 1068 and 622 is: False
# The shortest distance between 1513 and 2704 is: False
# The shortest distance between 1875 and 1429 is: False
# The shortest distance between 1881 and 1337 is: False
# The shortest distance between 2288 and 1540 is: False
# The shortest distance between 399 and 1345 is: False
# The shortest distance between 1955 and 1652 is: False
# The shortest distance between 1630 and 2607 is: False
# The shortest distance between 196 and 1787 is: False
# The shortest distance between 2193 and 874 is: False
# The shortest distance between 235 and 1912 is: False
# The shortest distance between 1567 and 592 is: False
# The shortest distance between 1266 and 1436 is: False
# The shortest distance between 2129 and 2654 is: False
# The shortest distance between 2255 and 526 is: False
# The shortest distance between 1640 and 1792 is: False
# The shortest distance between 1812 and 1378 is: False
# The shortest distance between 2513 and 1718 is: False
# The shortest distance between 149 and 213 is: False
# The shortest distance between 101 and 2011 is: False
# The shortest distance between 1994 and 314 is: False
# The shortest distance between 2087 and 1473 is: False
# The shortest distance between 1286 and 2442 is: False
# The shortest distance between 2376 and 1692 is: False
# The shortest distance between 2512 and 1784 is: False
# The shortest distance between 80 and 349 is: False
# The shortest distance between 2274 and 1093 is: False
# The shortest distance between 795 and 90 is: False
# The shortest distance between 2438 and 1737 is: False
# The shortest distance between 1982 and 1615 is: False
# The shortest distance between 1110 and 2674 is: False
# The shortest distance between 426 and 1225 is: False
# The shortest distance between 1721 and 343 is: False
# The shortest distance between 870 and 196 is: False
# The shortest distance between 2102 and 1335 is: False
# The shortest distance between 470 and 1795 is: False
# The shortest distance between 1954 and 27 is: False
# The shortest distance between 1659 and 1815 is: False
# The shortest distance between 1980 and 2281 is: False
# The shortest distance between 902 and 1758 is: False
# The shortest distance between 1520 and 1992 is: False
# The shortest distance between 1502 and 23 is: False
# The shortest distance between 39 and 2152 is: False
# The shortest distance between 1050 and 178 is: False
# The shortest distance between 391 and 2626 is: False
# The shortest distance between 2597 and 1908 is: False
# The shortest distance between 1551 and 2669 is: False
# The shortest distance between 632 and 2451 is: False
# The shortest distance between 64 and 2636 is: False
# The shortest distance between 1579 and 48 is: False
# The shortest distance between 1105 and 1051 is: False
# The shortest distance between 2086 and 1569 is: False
# The shortest distance between 2217 and 572 is: False
# The shortest distance between 132 and 1027 is: False
# The shortest distance between 207 and 987 is: False
# The shortest distance between 1808 and 1365 is: False
# The shortest distance between 521 and 2353 is: False
# The shortest distance between 58 and 107 is: False
# The shortest distance between 62 and 730 is: False
# The shortest distance between 382 and 2006 is: False
# The shortest distance between 409 and 2351 is: False
# The shortest distance between 9 and 1255 is: False
# The shortest distance between 242 and 1419 is: False
# The shortest distance between 1870 and 2570 is: False
# The shortest distance between 1505 and 482 is: False
# The shortest distance between 779 and 2206 is: False
# The shortest distance between 929 and 2084 is: False
# The shortest distance between 2451 and 2528 is: False
# The shortest distance between 1184 and 484 is: False
# The shortest distance between 449 and 2053 is: False
# The shortest distance between 1041 and 428 is: False
# The shortest distance between 953 and 1458 is: False
# The shortest distance between 1393 and 2143 is: False
# The shortest distance between 2038 and 917 is: False
# The shortest distance between 866 and 2214 is: False
# The shortest distance between 321 and 660 is: False
# The shortest distance between 2489 and 1423 is: False
# The shortest distance between 1817 and 42 is: False
# The shortest distance between 1186 and 376 is: False
# The shortest distance between 285 and 779 is: False
# The shortest distance between 345 and 1364 is: False
# The shortest distance between 1668 and 1257 is: False
# The shortest distance between 433 and 764 is: False
# The shortest distance between 1107 and 994 is: False
# The shortest distance between 2504 and 1153 is: False
# The shortest distance between 2316 and 1715 is: False
# The shortest distance between 928 and 2196 is: False
# The shortest distance between 2392 and 1033 is: False
# The shortest distance between 622 and 2108 is: False
# The shortest distance between 1240 and 2334 is: False
# The shortest distance between 2658 and 1239 is: False
# The shortest distance between 1 and 1226 is: False
# The shortest distance between 320 and 2294 is: False
# The shortest distance between 398 and 115 is: False
# The shortest distance between 1085 and 676 is: False
# The shortest distance between 957 and 160 is: False
# The shortest distance between 834 and 553 is: False
# The shortest distance between 992 and 264 is: False
# The shortest distance between 1018 and 928 is: False
# The shortest distance between 2195 and 2157 is: False
# The shortest distance between 1543 and 1312 is: False
# The shortest distance between 2591 and 763 is: False
# The shortest distance between 2072 and 2049 is: False
# The shortest distance between 2444 and 572 is: False
# The shortest distance between 650 and 2065 is: False
# The shortest distance between 1448 and 2374 is: False
# The shortest distance between 1142 and 2527 is: False
# The shortest distance between 255 and 2403 is: False
# The shortest distance between 2299 and 498 is: False
# The shortest distance between 1788 and 172 is: False
# The shortest distance between 74 and 576 is: False
# The shortest distance between 521 and 769 is: False
# The shortest distance between 293 and 1019 is: False
# The shortest distance between 395 and 1758 is: False
# The shortest distance between 571 and 669 is: False
# The shortest distance between 2614 and 1331 is: False
# The shortest distance between 196 and 2340 is: False
# The shortest distance between 1513 and 1413 is: False
# The shortest distance between 2362 and 2269 is: False
# The shortest distance between 1739 and 1793 is: False
# The shortest distance between 300 and 2305 is: False
# The shortest distance between 1101 and 1384 is: False
# The shortest distance between 1606 and 188 is: False
# The shortest distance between 1547 and 699 is: False
# The shortest distance between 2583 and 1299 is: False
# The shortest distance between 1802 and 975 is: False
# The shortest distance between 1394 and 964 is: False
# The shortest distance between 2220 and 1407 is: False
# The shortest distance between 17 and 1064 is: False
# The shortest distance between 199 and 352 is: False
# The shortest distance between 1219 and 1017 is: False
# The shortest distance between 2599 and 72 is: False
# The shortest distance between 1267 and 2682 is: False
# The shortest distance between 313 and 1923 is: False
# The shortest distance between 390 and 332 is: False
# The shortest distance between 48 and 1039 is: False
# The shortest distance between 1504 and 2518 is: False
# The shortest distance between 1486 and 87 is: False
# The shortest distance between 745 and 1071 is: False
# The shortest distance between 821 and 1993 is: False
# The shortest distance between 103 and 1105 is: False
# The shortest distance between 2301 and 1982 is: False
# The shortest distance between 2567 and 368 is: False
# The shortest distance between 1278 and 2220 is: False
# The shortest distance between 623 and 564 is: False
# The shortest distance between 931 and 1620 is: False
# The shortest distance between 483 and 793 is: False
# The shortest distance between 2297 and 2670 is: False
# The shortest distance between 1137 and 1872 is: False
# The shortest distance between 619 and 868 is: False
# The shortest distance between 360 and 2245 is: False
# The shortest distance between 1256 and 704 is: False
# The shortest distance between 701 and 2104 is: False
# The shortest distance between 588 and 2290 is: False
# The shortest distance between 876 and 794 is: False
# The shortest distance between 2615 and 2703 is: False
# The shortest distance between 1254 and 1900 is: False
# The shortest distance between 1934 and 932 is: False
# The shortest distance between 324 and 335 is: False
# The shortest distance between 806 and 1356 is: False
# The shortest distance between 478 and 1978 is: False
# The shortest distance between 1062 and 2145 is: False
# The shortest distance between 237 and 1104 is: False
# The shortest distance between 73 and 612 is: False
# The shortest distance between 1527 and 1104 is: False
# The shortest distance between 1208 and 1292 is: False
# The shortest distance between 1326 and 637 is: False
# The shortest distance between 2447 and 2165 is: False
# The shortest distance between 1746 and 2130 is: False
# The shortest distance between 990 and 267 is: False
# The shortest distance between 1223 and 1019 is: False
# The shortest distance between 212 and 313 is: False
# The shortest distance between 226 and 749 is: False
# The shortest distance between 698 and 2123 is: False
# The shortest distance between 843 and 768 is: False
# The shortest distance between 545 and 31 is: False
# The shortest distance between 2536 and 1166 is: False
# The shortest distance between 1264 and 1609 is: False
# The shortest distance between 1851 and 2054 is: False
# The shortest distance between 1701 and 1705 is: False
# The shortest distance between 645 and 833 is: False
# The shortest distance between 1817 and 447 is: False
# The shortest distance between 2051 and 418 is: False
# The shortest distance between 2665 and 1214 is: False
# The shortest distance between 923 and 183 is: False
# The shortest distance between 1399 and 2221 is: False
# The shortest distance between 2556 and 7 is: False
# The shortest distance between 1629 and 2225 is: False
# The shortest distance between 1862 and 2290 is: False
# The shortest distance between 157 and 618 is: False
# The shortest distance between 2646 and 449 is: False
# The shortest distance between 1673 and 691 is: False
# The shortest distance between 2542 and 535 is: False
# The shortest distance between 515 and 1142 is: False
# The shortest distance between 1230 and 2585 is: False
# The shortest distance between 808 and 2579 is: False
# The shortest distance between 1806 and 654 is: False
# The shortest distance between 729 and 900 is: False
# The shortest distance between 1704 and 155 is: False
# The shortest distance between 1668 and 1931 is: False
# The shortest distance between 1437 and 2029 is: False
# The shortest distance between 797 and 267 is: False
# The shortest distance between 868 and 1097 is: False
# The shortest distance between 590 and 2395 is: False
# The shortest distance between 573 and 303 is: False
# The shortest distance between 586 and 2131 is: False
# The shortest distance between 1257 and 615 is: False
# The shortest distance between 1512 and 1070 is: False
# The shortest distance between 438 and 2079 is: False
# The shortest distance between 164 and 742 is: False
# The shortest distance between 1079 and 753 is: False
# The shortest distance between 1463 and 1956 is: False
# The shortest distance between 2184 and 1409 is: False
# The shortest distance between 571 and 1084 is: False
# The shortest distance between 825 and 482 is: False
# The shortest distance between 1613 and 1730 is: False
# The shortest distance between 1689 and 996 is: False
# The shortest distance between 2680 and 156 is: False
# The shortest distance between 317 and 1215 is: False
# The shortest distance between 805 and 2330 is: False
# The shortest distance between 2638 and 1747 is: False
# The shortest distance between 848 and 2280 is: False
# The shortest distance between 1531 and 1082 is: False
# The shortest distance between 83 and 1129 is: False
# The shortest distance between 1300 and 38 is: False
# The shortest distance between 1124 and 835 is: False
# The shortest distance between 875 and 1265 is: False
# The shortest distance between 1154 and 1360 is: False
# The shortest distance between 2654 and 1594 is: False
# The shortest distance between 140 and 2405 is: False
# The shortest distance between 825 and 459 is: False
# The shortest distance between 980 and 785 is: False
# The shortest distance between 2234 and 1746 is: False
# The shortest distance between 744 and 1454 is: False
# The shortest distance between 1536 and 2015 is: False
# The shortest distance between 1857 and 2106 is: False
# The shortest distance between 1524 and 122 is: False
# The shortest distance between 1224 and 37 is: False
# The shortest distance between 997 and 765 is: False
# The shortest distance between 1573 and 849 is: False
# The shortest distance between 548 and 498 is: False
# The shortest distance between 506 and 2216 is: False
# The shortest distance between 1453 and 761 is: False
# The shortest distance between 1837 and 172 is: False
# The shortest distance between 2631 and 1542 is: False
# The shortest distance between 1636 and 142 is: False
# The shortest distance between 452 and 1458 is: False
# The shortest distance between 1024 and 1272 is: False
# The shortest distance between 2071 and 1110 is: False
# The shortest distance between 1160 and 780 is: False
# The shortest distance between 1391 and 446 is: False
# The shortest distance between 313 and 1934 is: False
# The shortest distance between 669 and 2035 is: False
# The shortest distance between 822 and 1164 is: False
# The shortest distance between 503 and 2346 is: False
# The shortest distance between 1914 and 1982 is: False
# The shortest distance between 1275 and 786 is: False
# The shortest distance between 1184 and 1988 is: False
# The shortest distance between 140 and 2146 is: False
# The shortest distance between 2460 and 17 is: False
# The shortest distance between 1211 and 230 is: False
# The shortest distance between 2455 and 932 is: False
# The shortest distance between 957 and 1736 is: False
# The shortest distance between 523 and 1152 is: False
# The shortest distance between 1669 and 515 is: False
# The shortest distance between 399 and 1254 is: False
# The shortest distance between 1378 and 1864 is: False
# The shortest distance between 1407 and 2077 is: False
# The shortest distance between 2419 and 1100 is: False
# The shortest distance between 314 and 1449 is: False
# The shortest distance between 2673 and 539 is: False
# The shortest distance between 129 and 2267 is: False
# The shortest distance between 2038 and 2394 is: False
# The shortest distance between 368 and 1228 is: False
# The shortest distance between 528 and 2538 is: False
# The shortest distance between 978 and 1994 is: False
# The shortest distance between 2664 and 813 is: False
# The shortest distance between 151 and 2468 is: False
# The shortest distance between 927 and 1474 is: False
# The shortest distance between 12 and 757 is: False
# The shortest distance between 1038 and 2089 is: False
# The shortest distance between 1907 and 2701 is: False
# The shortest distance between 750 and 924 is: False
# The shortest distance between 1612 and 1621 is: False
# The shortest distance between 2150 and 1939 is: False
# The shortest distance between 1009 and 1429 is: False
# The shortest distance between 1666 and 1533 is: False
# The shortest distance between 1009 and 1941 is: False
# The shortest distance between 822 and 706 is: False
# The shortest distance between 2183 and 1278 is: False
# The shortest distance between 497 and 178 is: False
# The shortest distance between 359 and 1406 is: False
# The shortest distance between 1934 and 441 is: False
# The shortest distance between 200 and 2686 is: False
# The shortest distance between 682 and 2097 is: False
# The shortest distance between 1072 and 1570 is: False
# The shortest distance between 585 and 11 is: False
# The shortest distance between 548 and 2462 is: False
# The shortest distance between 2271 and 984 is: False
# The shortest distance between 50 and 2275 is: False
# The shortest distance between 1285 and 340 is: False
# The shortest distance between 606 and 981 is: False
# The shortest distance between 363 and 57 is: False
# The shortest distance between 2327 and 2579 is: False
# The shortest distance between 2587 and 348 is: False
# The shortest distance between 2422 and 1646 is: False
# The shortest distance between 1943 and 2208 is: False
# The shortest distance between 1883 and 646 is: False
# The shortest distance between 1703 and 83 is: False
# The shortest distance between 2308 and 2355 is: False
# The shortest distance between 1575 and 1106 is: False
# The shortest distance between 2347 and 543 is: False
# The shortest distance between 2582 and 1597 is: False
# The shortest distance between 1617 and 875 is: False
# The shortest distance between 765 and 1287 is: False
# The shortest distance between 87 and 2132 is: False
# The shortest distance between 2701 and 2453 is: False
# The shortest distance between 2422 and 823 is: False
# The shortest distance between 1376 and 2366 is: False
# The shortest distance between 1542 and 425 is: False
# The shortest distance between 341 and 232 is: False
# The shortest distance between 992 and 1304 is: False
# The shortest distance between 2215 and 499 is: False
# The shortest distance between 1236 and 492 is: False
# The shortest distance between 2206 and 2110 is: False
# The shortest distance between 1534 and 2571 is: False
# The shortest distance between 2049 and 292 is: False
# The shortest distance between 297 and 2485 is: False
# The shortest distance between 1789 and 927 is: False
# The shortest distance between 650 and 2439 is: False
# The shortest distance between 2543 and 1637 is: False
# The shortest distance between 39 and 2019 is: False
# The shortest distance between 1187 and 899 is: False
# The shortest distance between 1651 and 1117 is: False
# The shortest distance between 659 and 1329 is: False
# The shortest distance between 963 and 1161 is: False
# The shortest distance between 961 and 1368 is: False
# The shortest distance between 1213 and 2315 is: False
# The shortest distance between 838 and 989 is: False
# The shortest distance between 1225 and 1877 is: False
# The shortest distance between 2557 and 878 is: False
# The shortest distance between 2327 and 845 is: False
# The shortest distance between 78 and 2224 is: False
# The shortest distance between 747 and 1928 is: False
# The shortest distance between 168 and 717 is: False
# The shortest distance between 1297 and 2236 is: False
# The shortest distance between 584 and 228 is: False
# The shortest distance between 1232 and 1895 is: False
# The shortest distance between 1163 and 1045 is: False
# The shortest distance between 305 and 1460 is: False
# The shortest distance between 2356 and 231 is: False
# The shortest distance between 2355 and 1984 is: False
# The shortest distance between 1616 and 1513 is: False
# The shortest distance between 371 and 2526 is: False
# The shortest distance between 2530 and 891 is: False
# The shortest distance between 1452 and 1473 is: False
# The shortest distance between 2685 and 2558 is: False
# The shortest distance between 2438 and 2442 is: False
# The shortest distance between 811 and 1866 is: False
# The shortest distance between 1419 and 2332 is: False
# The shortest distance between 1379 and 1571 is: False
# The shortest distance between 1450 and 2412 is: False
# The shortest distance between 1074 and 274 is: False
# The shortest distance between 2289 and 1929 is: False
# The shortest distance between 2560 and 1699 is: False
# The shortest distance between 249 and 964 is: False
# The shortest distance between 848 and 2548 is: False
# The shortest distance between 557 and 801 is: False
# The shortest distance between 1381 and 934 is: False
# The shortest distance between 2153 and 1285 is: False
# The shortest distance between 323 and 405 is: False
# The shortest distance between 2574 and 353 is: False
# The shortest distance between 634 and 13 is: False
# The shortest distance between 2603 and 551 is: False
# The shortest distance between 1685 and 1092 is: False
# The shortest distance between 2419 and 327 is: False
# The shortest distance between 1774 and 1310 is: False
# The shortest distance between 2059 and 511 is: False
# The shortest distance between 446 and 2498 is: False
# The shortest distance between 1787 and 2098 is: False
# The shortest distance between 1056 and 1972 is: False
# The shortest distance between 239 and 2290 is: False
# The shortest distance between 1782 and 800 is: False
# The shortest distance between 721 and 1607 is: False
# The shortest distance between 1721 and 883 is: False
# The shortest distance between 1784 and 450 is: False
# The shortest distance between 1440 and 1340 is: False
# The shortest distance between 2068 and 996 is: False
# The shortest distance between 547 and 1322 is: False
# The shortest distance between 1097 and 2509 is: False
# The shortest distance between 2433 and 2481 is: False
# The shortest distance between 456 and 2456 is: False
# The shortest distance between 2554 and 2180 is: False
# The shortest distance between 1543 and 613 is: False
# The shortest distance between 210 and 202 is: False
# The shortest distance between 2441 and 1489 is: False
# The shortest distance between 42 and 1915 is: False
# The shortest distance between 1430 and 1047 is: False
# The shortest distance between 2195 and 1531 is: False
# The shortest distance between 1565 and 958 is: False
# The shortest distance between 1464 and 670 is: False
# The shortest distance between 1937 and 256 is: False
# The shortest distance between 2571 and 1530 is: False
# The shortest distance between 81 and 1724 is: False
# The shortest distance between 2366 and 141 is: False
# The shortest distance between 1289 and 1809 is: False
# The shortest distance between 2343 and 2470 is: False
# The shortest distance between 1220 and 1590 is: False
# The shortest distance between 763 and 771 is: False
# The shortest distance between 2157 and 1958 is: False
# The shortest distance between 519 and 624 is: False
# The shortest distance between 1370 and 1838 is: False
# The shortest distance between 1039 and 24 is: False
# The shortest distance between 1877 and 417 is: False
# The shortest distance between 2524 and 2528 is: False
# The shortest distance between 1151 and 2033 is: False
# The shortest distance between 1027 and 1759 is: False
# The shortest distance between 1989 and 1837 is: False
# The shortest distance between 2064 and 1104 is: False
# The shortest distance between 2019 and 2272 is: False
# The shortest distance between 374 and 1835 is: False
# The shortest distance between 1984 and 148 is: False
# The shortest distance between 1705 and 406 is: False
# The shortest distance between 344 and 2648 is: False
# The shortest distance between 1748 and 111 is: False
# The shortest distance between 2282 and 1761 is: False
# The shortest distance between 363 and 679 is: False
# The shortest distance between 1507 and 1268 is: False
# The shortest distance between 445 and 2517 is: False
# The shortest distance between 923 and 2451 is: False
# The shortest distance between 819 and 1940 is: False
# The shortest distance between 661 and 1881 is: False
# The shortest distance between 2043 and 1912 is: False
# The shortest distance between 1367 and 1651 is: False
# The shortest distance between 1235 and 2104 is: False
# The shortest distance between 2562 and 610 is: False
# The shortest distance between 1583 and 2100 is: False
# The shortest distance between 557 and 2030 is: False
# The shortest distance between 1437 and 2039 is: False
# The shortest distance between 2365 and 2071 is: False
# The shortest distance between 646 and 1912 is: False
# The shortest distance between 199 and 2511 is: False
# The shortest distance between 1426 and 420 is: False
# The shortest distance between 1228 and 885 is: False
# The shortest distance between 1608 and 2363 is: False
# The shortest distance between 1595 and 282 is: False
# The shortest distance between 2451 and 2514 is: False
# The shortest distance between 1996 and 228 is: False
# The shortest distance between 938 and 2583 is: False
# The shortest distance between 2423 and 1498 is: False
# The shortest distance between 2321 and 1973 is: False
# The shortest distance between 970 and 1321 is: False
# The shortest distance between 1207 and 199 is: False
# The shortest distance between 2140 and 911 is: False
# The shortest distance between 2643 and 457 is: False
# The shortest distance between 2694 and 234 is: False
# The shortest distance between 2597 and 141 is: False
# The shortest distance between 2555 and 899 is: False
# The shortest distance between 788 and 740 is: False
# The shortest distance between 2029 and 376 is: False
# The shortest distance between 584 and 1913 is: False
# The shortest distance between 1751 and 1950 is: False
# The shortest distance between 108 and 1956 is: False
# The shortest distance between 2480 and 1316 is: False
# The shortest distance between 1405 and 41 is: False
# The shortest distance between 1569 and 2002 is: False
# The shortest distance between 322 and 2434 is: False
# The shortest distance between 559 and 298 is: False
# The shortest distance between 1138 and 340 is: False
# The shortest distance between 933 and 1840 is: False
# The shortest distance between 781 and 1128 is: False
# The shortest distance between 1116 and 1550 is: False
# The shortest distance between 2010 and 876 is: False
# The shortest distance between 144 and 2619 is: False
# The shortest distance between 2628 and 539 is: False
# The shortest distance between 1605 and 401 is: False
# The shortest distance between 2472 and 1550 is: False
# The shortest distance between 1624 and 2061 is: False
# The shortest distance between 676 and 536 is: False
# The shortest distance between 1206 and 1148 is: False
# The shortest distance between 1351 and 214 is: False
# The shortest distance between 2021 and 2076 is: False
# The shortest distance between 1673 and 1266 is: False
# The shortest distance between 1489 and 1156 is: False
# The shortest distance between 787 and 926 is: False
# The shortest distance between 1973 and 200 is: False
# The shortest distance between 1927 and 2203 is: False
# The shortest distance between 2471 and 1287 is: False
# The shortest distance between 2172 and 177 is: False
# The shortest distance between 579 and 2497 is: False
# The shortest distance between 1886 and 2670 is: False
# The shortest distance between 435 and 1938 is: False
# The shortest distance between 2594 and 398 is: False
# The shortest distance between 1320 and 693 is: False
# The shortest distance between 689 and 226 is: False
# The shortest distance between 1052 and 2262 is: False
# The shortest distance between 1992 and 194 is: False
# The shortest distance between 1123 and 337 is: False
# The shortest distance between 417 and 814 is: False
# The shortest distance between 1321 and 653 is: False
# The shortest distance between 2193 and 160 is: False
# The shortest distance between 2314 and 681 is: False
# The shortest distance between 305 and 1954 is: False
# The shortest distance between 943 and 712 is: False
# The shortest distance between 548 and 2038 is: False
# The shortest distance between 126 and 636 is: False
# The shortest distance between 2560 and 834 is: False
# The shortest distance between 2036 and 50 is: False
# The shortest distance between 193 and 1841 is: False
# The shortest distance between 786 and 1156 is: False
# The shortest distance between 345 and 1288 is: False
# The shortest distance between 892 and 495 is: False
# The shortest distance between 640 and 124 is: False
# The shortest distance between 5 and 1848 is: False
# The shortest distance between 1451 and 2640 is: False
# The shortest distance between 2528 and 673 is: False
# The shortest distance between 80 and 2069 is: False
# The shortest distance between 1683 and 452 is: False
# The shortest distance between 683 and 17 is: False
# The shortest distance between 2640 and 1351 is: False
# The shortest distance between 2374 and 1236 is: False
# The shortest distance between 1297 and 359 is: False
# The shortest distance between 1874 and 329 is: False
# The shortest distance between 1408 and 329 is: False
# The shortest distance between 1278 and 2666 is: False
# The shortest distance between 1989 and 757 is: False
# The shortest distance between 1380 and 2340 is: False
# The shortest distance between 1857 and 1777 is: False
# The shortest distance between 1884 and 314 is: False
# The shortest distance between 1267 and 963 is: False
# The shortest distance between 1683 and 1647 is: False
# The shortest distance between 979 and 1254 is: False
# The shortest distance between 317 and 689 is: False
# The shortest distance between 2073 and 2228 is: False
# The shortest distance between 650 and 125 is: False
# The shortest distance between 1755 and 2369 is: False
# The shortest distance between 276 and 377 is: False
# The shortest distance between 1724 and 1230 is: False
# The shortest distance between 1361 and 340 is: False
# The shortest distance between 2134 and 2334 is: False
# The shortest distance between 2394 and 581 is: False
# The shortest distance between 1690 and 2246 is: False
# The shortest distance between 1179 and 2482 is: False
# The shortest distance between 2191 and 1361 is: False
# The shortest distance between 2207 and 2308 is: False
# The shortest distance between 2666 and 2176 is: False
# The shortest distance between 2256 and 1142 is: False
# The shortest distance between 2646 and 1558 is: False
# The shortest distance between 1973 and 323 is: False
# The shortest distance between 2671 and 247 is: False
# The shortest distance between 521 and 1956 is: False
# The shortest distance between 404 and 2269 is: False
# The shortest distance between 1551 and 29 is: False
# The shortest distance between 2559 and 2362 is: False
# The shortest distance between 507 and 523 is: False
# The shortest distance between 528 and 2457 is: False
# The shortest distance between 2195 and 2292 is: False
# The shortest distance between 1475 and 991 is: False
# The shortest distance between 85 and 1920 is: False
# The shortest distance between 1815 and 2425 is: False
# The shortest distance between 1795 and 772 is: False
# The shortest distance between 2441 and 1318 is: False
# The shortest distance between 1311 and 1086 is: False
# The shortest distance between 130 and 2563 is: False
# The shortest distance between 1909 and 773 is: False
# The shortest distance between 696 and 1380 is: False
# The shortest distance between 1156 and 741 is: False
# The shortest distance between 1233 and 1754 is: False
# The shortest distance between 1862 and 299 is: False
# The shortest distance between 1252 and 2315 is: False
# The shortest distance between 985 and 156 is: False
# The shortest distance between 1817 and 1706 is: False
# The shortest distance between 2702 and 2546 is: False
# The shortest distance between 474 and 464 is: False
# The shortest distance between 2094 and 24 is: False
# The shortest distance between 2233 and 1282 is: False
# The shortest distance between 919 and 711 is: False
# The shortest distance between 1037 and 938 is: False
# The shortest distance between 1504 and 1803 is: False
# The shortest distance between 1442 and 722 is: False
# The shortest distance between 1668 and 734 is: False
# The shortest distance between 1276 and 2454 is: False
# The shortest distance between 374 and 1800 is: False
# The shortest distance between 1433 and 183 is: False
# The shortest distance between 1234 and 1273 is: False
# The shortest distance between 1109 and 961 is: False
# The shortest distance between 774 and 1634 is: False
# The shortest distance between 2522 and 484 is: False
# The shortest distance between 2448 and 280 is: False
# The shortest distance between 1316 and 807 is: False
# The shortest distance between 2655 and 2364 is: False
# The shortest distance between 1035 and 827 is: False
# The shortest distance between 284 and 1015 is: False
# The shortest distance between 395 and 1813 is: False
# The shortest distance between 1595 and 1899 is: False
# The shortest distance between 911 and 1882 is: False
# The shortest distance between 1578 and 1768 is: False
# The shortest distance between 2683 and 786 is: False
# The shortest distance between 1904 and 1548 is: False
# The shortest distance between 991 and 1830 is: False
# The shortest distance between 504 and 1899 is: False
# The shortest distance between 2066 and 873 is: False
# The shortest distance between 168 and 364 is: False
# The shortest distance between 2051 and 1511 is: False
# The shortest distance between 980 and 1012 is: False
# The shortest distance between 1597 and 518 is: False
# The shortest distance between 2421 and 1182 is: False
# The shortest distance between 739 and 1699 is: False
# The shortest distance between 1603 and 2168 is: False
# The shortest distance between 1173 and 72 is: False
# The shortest distance between 391 and 2454 is: False
# The shortest distance between 1563 and 327 is: False
# The shortest distance between 553 and 621 is: False
# The shortest distance between 2018 and 1516 is: False
# The shortest distance between 74 and 1805 is: False
# The shortest distance between 2608 and 762 is: False
# The shortest distance between 515 and 1038 is: False
# The shortest distance between 1455 and 2534 is: False
# The shortest distance between 1097 and 905 is: False
# The shortest distance between 2110 and 286 is: False
# The shortest distance between 1267 and 576 is: False
# The shortest distance between 1943 and 248 is: False
# The shortest distance between 837 and 335 is: False
# The shortest distance between 2024 and 1939 is: False
# The shortest distance between 996 and 1288 is: False
# The shortest distance between 31 and 1803 is: False
# The shortest distance between 2000 and 1609 is: False
# The shortest distance between 447 and 378 is: False
# The shortest distance between 579 and 1463 is: False
# The shortest distance between 2199 and 1080 is: False
# The shortest distance between 2486 and 95 is: False
# The shortest distance between 2493 and 983 is: False
# The shortest distance between 663 and 208 is: False
# The shortest distance between 2282 and 1312 is: False
# The shortest distance between 2515 and 1938 is: False
# The shortest distance between 2234 and 907 is: False
# The shortest distance between 905 and 984 is: False
# The shortest distance between 2296 and 884 is: False
# The shortest distance between 2213 and 2692 is: False
# The shortest distance between 20 and 1026 is: False
# The shortest distance between 1780 and 267 is: False
# The shortest distance between 1432 and 1532 is: False
# The shortest distance between 2678 and 1529 is: False
# The shortest distance between 670 and 1685 is: False
# The shortest distance between 1520 and 1707 is: False
# The shortest distance between 1876 and 1320 is: False
# The shortest distance between 115 and 2004 is: False
# The shortest distance between 937 and 1754 is: False
# The shortest distance between 1896 and 1683 is: False
# The shortest distance between 2539 and 785 is: False
# The shortest distance between 1768 and 32 is: False
# The shortest distance between 890 and 2363 is: False
# The shortest distance between 2321 and 480 is: False
# The shortest distance between 139 and 1624 is: False
# The shortest distance between 2347 and 1837 is: False
# The shortest distance between 4 and 2508 is: False
# The shortest distance between 964 and 415 is: False
# The shortest distance between 1559 and 2611 is: False
# The shortest distance between 2207 and 2569 is: False
# The shortest distance between 2070 and 2602 is: False
# The shortest distance between 941 and 1201 is: False
# The shortest distance between 480 and 261 is: False
# The shortest distance between 1943 and 2573 is: False
# The shortest distance between 336 and 1262 is: False
# The shortest distance between 670 and 2014 is: False
# The shortest distance between 1953 and 427 is: False
# The shortest distance between 581 and 1005 is: False
# The shortest distance between 989 and 1570 is: False
# The shortest distance between 2688 and 441 is: False
# The shortest distance between 2104 and 2547 is: False
# The shortest distance between 12 and 205 is: False
# The shortest distance between 1471 and 412 is: False
# The shortest distance between 2094 and 2642 is: False
# The shortest distance between 206 and 1742 is: False
# The shortest distance between 2304 and 2336 is: False
# The shortest distance between 488 and 233 is: False
# The shortest distance between 556 and 1396 is: False
# The shortest distance between 988 and 2488 is: False
# The shortest distance between 507 and 687 is: False
# The shortest distance between 2628 and 859 is: False
# The shortest distance between 2089 and 924 is: False
# The shortest distance between 1602 and 748 is: False
# The shortest distance between 658 and 583 is: False
# The shortest distance between 1085 and 2569 is: False
# The shortest distance between 2087 and 2531 is: False
# The shortest distance between 1937 and 1217 is: False
# The shortest distance between 1216 and 2148 is: False
# The shortest distance between 2544 and 506 is: False
# The shortest distance between 776 and 1973 is: False
# The shortest distance between 2434 and 413 is: False
# The shortest distance between 1333 and 1379 is: False
# The shortest distance between 2453 and 782 is: False
# The shortest distance between 2070 and 87 is: False
# The shortest distance between 167 and 2262 is: False
# The shortest distance between 2434 and 782 is: False
# The shortest distance between 2617 and 917 is: False
# The shortest distance between 493 and 581 is: False
# The shortest distance between 2265 and 1317 is: False
# The shortest distance between 259 and 1111 is: False
# The shortest distance between 1616 and 29 is: False
# The shortest distance between 1785 and 1389 is: False
# The shortest distance between 837 and 1976 is: False
# The shortest distance between 2204 and 89 is: False
# The shortest distance between 1713 and 2544 is: False
# The shortest distance between 1305 and 2004 is: False
# The shortest distance between 2120 and 435 is: False
# The shortest distance between 1161 and 2597 is: False
# The shortest distance between 1837 and 802 is: False
# The shortest distance between 217 and 2508 is: False
# The shortest distance between 735 and 729 is: False
# The shortest distance between 120 and 194 is: False
# The shortest distance between 1258 and 2398 is: False
# The shortest distance between 449 and 1804 is: False
# The shortest distance between 2133 and 1681 is: False
# The shortest distance between 2156 and 1667 is: False
# The shortest distance between 1613 and 1400 is: False
# The shortest distance between 1652 and 2306 is: False
# The shortest distance between 777 and 2229 is: False
# The shortest distance between 1581 and 1680 is: False
# The shortest distance between 503 and 1482 is: False
# The shortest distance between 509 and 1474 is: False
# The shortest distance between 1733 and 1051 is: False
# The shortest distance between 2329 and 2685 is: False
# The shortest distance between 1203 and 1546 is: False
# The shortest distance between 1617 and 1388 is: False
# The shortest distance between 505 and 2228 is: False
# The shortest distance between 2055 and 108 is: False
# The shortest distance between 1559 and 2322 is: False
# The shortest distance between 344 and 2538 is: False
# The shortest distance between 608 and 1096 is: False
# The shortest distance between 2079 and 2133 is: False
# The shortest distance between 2350 and 2135 is: False
# The shortest distance between 2610 and 1506 is: False
# The shortest distance between 1660 and 2584 is: False
# The shortest distance between 981 and 2393 is: False
# The shortest distance between 2243 and 1721 is: False
# The shortest distance between 1565 and 1064 is: False
# The shortest distance between 205 and 1030 is: False
# The shortest distance between 2400 and 2181 is: False
# The shortest distance between 2329 and 1661 is: False
# The shortest distance between 1554 and 2202 is: False
# The shortest distance between 2220 and 1062 is: False
# The shortest distance between 2699 and 1277 is: False
# The shortest distance between 830 and 2086 is: False
# The shortest distance between 1374 and 1206 is: False
# The shortest distance between 612 and 1896 is: False
# The shortest distance between 1803 and 1425 is: False
# The shortest distance between 1733 and 2184 is: False
# The shortest distance between 2541 and 1704 is: False
# The shortest distance between 1197 and 967 is: False
# The shortest distance between 838 and 990 is: False
# The shortest distance between 1323 and 307 is: False
# The shortest distance between 2149 and 704 is: False
# The shortest distance between 2518 and 1726 is: False
# The shortest distance between 9 and 1408 is: False
# The shortest distance between 1857 and 1972 is: False
# The shortest distance between 1761 and 1557 is: False
# The shortest distance between 1455 and 2471 is: False
# The shortest distance between 724 and 1385 is: False
# The shortest distance between 611 and 2617 is: False
# The shortest distance between 2484 and 1660 is: False
# The shortest distance between 579 and 1073 is: False
# The shortest distance between 39 and 1778 is: False
# The shortest distance between 2385 and 364 is: False
# The shortest distance between 902 and 2265 is: False
# The shortest distance between 2145 and 2160 is: False
# The shortest distance between 1947 and 1020 is: False
# The shortest distance between 2273 and 53 is: False
# The shortest distance between 2640 and 961 is: False
# The shortest distance between 2209 and 1872 is: False
# The shortest distance between 1552 and 691 is: False
# The shortest distance between 100 and 1303 is: False
# The shortest distance between 700 and 2624 is: False
# The shortest distance between 1998 and 1191 is: False
# The shortest distance between 2507 and 2501 is: False
# The shortest distance between 1795 and 1496 is: False
# The shortest distance between 1629 and 2358 is: False
# The shortest distance between 672 and 1681 is: False
# The shortest distance between 291 and 504 is: False
# The shortest distance between 186 and 527 is: False
# The shortest distance between 1735 and 2361 is: False
# The shortest distance between 1404 and 1632 is: False
# The shortest distance between 2018 and 738 is: False
# The shortest distance between 679 and 1761 is: False
# The shortest distance between 1694 and 162 is: False
# The shortest distance between 956 and 2413 is: False
# The shortest distance between 228 and 1339 is: False
# The shortest distance between 2538 and 2524 is: False
# The shortest distance between 416 and 620 is: False
# The shortest distance between 1921 and 514 is: False
# The shortest distance between 1467 and 2402 is: False
# The shortest distance between 2247 and 42 is: False
# The shortest distance between 36 and 2178 is: False
# The shortest distance between 2323 and 53 is: False
# The shortest distance between 2700 and 1116 is: False
# The shortest distance between 746 and 1253 is: False
# The shortest distance between 2307 and 303 is: False
# The shortest distance between 2303 and 2452 is: False
# The shortest distance between 113 and 1176 is: False
# The shortest distance between 2630 and 1800 is: False
# The shortest distance between 683 and 1675 is: False
# The shortest distance between 1998 and 706 is: False
# The shortest distance between 1101 and 1612 is: False
# The shortest distance between 2288 and 1013 is: False
# The shortest distance between 1630 and 1446 is: False
# The shortest distance between 895 and 1290 is: False
# The shortest distance between 2411 and 1702 is: False
# The shortest distance between 2508 and 2390 is: False
# The shortest distance between 1879 and 2624 is: False
# The shortest distance between 128 and 1928 is: False
# The shortest distance between 1266 and 2115 is: False
# The shortest distance between 2368 and 1280 is: False
# The shortest distance between 331 and 1803 is: False
# The shortest distance between 516 and 1103 is: False
# The shortest distance between 1188 and 1251 is: False
# The shortest distance between 1649 and 384 is: False
# The shortest distance between 511 and 1970 is: False
# The shortest distance between 1240 and 1583 is: False
# The shortest distance between 2243 and 1490 is: False
# The shortest distance between 1182 and 2279 is: False
# The shortest distance between 1889 and 2203 is: False
# The shortest distance between 1217 and 1544 is: False
# The shortest distance between 892 and 1442 is: False
# The shortest distance between 2500 and 470 is: False
# The shortest distance between 999 and 977 is: False
# The shortest distance between 1773 and 2252 is: False
# The shortest distance between 1071 and 2201 is: False
# The shortest distance between 1525 and 897 is: False
# The shortest distance between 1645 and 225 is: False
# The shortest distance between 661 and 1343 is: False
# The shortest distance between 233 and 1576 is: False
# The shortest distance between 1229 and 1428 is: False
# The shortest distance between 594 and 1957 is: False
# The shortest distance between 704 and 1925 is: False
# The shortest distance between 1558 and 1832 is: False
# The shortest distance between 2228 and 2688 is: False
# The shortest distance between 1899 and 2497 is: False
# The shortest distance between 1762 and 393 is: False
# The shortest distance between 185 and 865 is: False
# The shortest distance between 2377 and 2591 is: False
# The shortest distance between 2197 and 2005 is: False
# The shortest distance between 2625 and 960 is: False
# The shortest distance between 1071 and 2273 is: False
# The shortest distance between 1277 and 2444 is: False
# The shortest distance between 998 and 541 is: False
# Average query time: 0.00007553
